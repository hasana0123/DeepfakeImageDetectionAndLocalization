# %%
import os
from PIL import Image
from torchvision import transforms

# %%
def upscale_image(image_path, upscale_target=(1920, 1080)):
    """
    Upscale the image to the target resolution while maintaining aspect ratio.
    
    Args:
        image_path (str): Path to the image file.
        upscale_target (tuple): Target resolution (width, height).
    
    Returns:
        Image: Upscaled image.
    """
    try:
        # Load the image
        image = Image.open(image_path).convert('RGB')
        print(f"Original size: {image.width}x{image.height}")

        # Adaptive upscaling based on target resolution
        if image.width < upscale_target[0] or image.height < upscale_target[1]:
            upscale_factor = min(upscale_target[0] / image.width, upscale_target[1] / image.height)
            new_width = int(image.width * upscale_factor)
            new_height = int(image.height * upscale_factor)
            image = image.resize((new_width, new_height), Image.BICUBIC)
            print(f"Upscaled to: {new_width}x{new_height}")
        
        return image
    
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return None

# %%
import os
from PIL import Image

def upscale_image(image_path, upscale_target=(1920, 1080)):
    """
    Upscale a given image to the target resolution using Bicubic interpolation.
    
    Args:
        image_path (str): Path to the image file.
        upscale_target (tuple): Target resolution (width, height) for upscaling.
    
    Returns:
        PIL.Image: Upscaled image.
    """
    try:
        # Open the image
        image = Image.open(image_path).convert('RGB')
        
        # Upscale the image using Bicubic interpolation
        upscaled_image = image.resize(upscale_target, Image.BICUBIC)
        return upscaled_image
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return None

def process_and_upscale_images(input_dir, output_dir, upscale_target=(1920, 1080)):
    """
    Process and upscale images from the input directory and save to the output directory, preserving folder structure.
    
    Args:
        input_dir (str): Path to the input directory containing 'train', 'test', 'validation' folders.
        output_dir (str): Path to the output directory where upscaled images will be saved.
        upscale_target (tuple): Target resolution (width, height) for upscaling.
    """
    # Process only the validation dataset folder
    dataset_name = 'validation'  # Process validation folder
    input_dataset_dir = os.path.join(input_dir, dataset_name)
    output_dataset_dir = os.path.join(output_dir, dataset_name)
    
    # Ensure output dataset directory exists
    os.makedirs(output_dataset_dir, exist_ok=True)

    # Iterate over all subdirectories (categories) in the validation dataset
    for category_name in os.listdir(input_dataset_dir):
        input_category_dir = os.path.join(input_dataset_dir, category_name)
        output_category_dir = os.path.join(output_dataset_dir, category_name)
        
        # Ensure output category directory exists
        os.makedirs(output_category_dir, exist_ok=True)

        # Iterate over each image in the category directory
        for image_name in os.listdir(input_category_dir):
            image_path = os.path.join(input_category_dir, image_name)
            
            # Skip directories or non-image files
            if os.path.isdir(image_path) or not image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                continue
            
            # Upscale the image
            upscaled_image = upscale_image(image_path, upscale_target)
            
            if upscaled_image:
                # Save the upscaled image to the output directory
                output_image_path = os.path.join(output_category_dir, image_name)
                upscaled_image.save(output_image_path)
                print(f"Processed and saved: {image_name} to {output_image_path}")
            else:
                print(f"Failed to process image {image_name}")

# %%
    # """
    # Process and upscale images from the input directory and save to the output directory, preserving folder structure.
    
    # Args:
    #     input_dir (str): Path to the input directory containing 'train', 'test', 'validate' folders.
    #     output_dir (str): Path to the output directory where upscaled images will be saved.
    #     upscale_target (tuple): Target resolution (width, height) for upscaling.
    # """
    # # Iterate over each dataset (train, test, validate)
    # for dataset_name in ['train', 'test', 'validate']:
    #     input_dataset_dir = os.path.join(input_dir, dataset_name)
    #     output_dataset_dir = os.path.join(output_dir, dataset_name)
        
    #     # Ensure output dataset directory exists
    #     os.makedirs(output_dataset_dir, exist_ok=True)

    #     # Iterate over aldef process_and_upscale_images(input_dir, output_dir, upscale_target=(1920, 1080)):l subdirectories (categories) in the dataset
    #     for category_name in os.listdir(input_dataset_dir):
    #         input_category_dir = os.path.join(input_dataset_dir, category_name)
    #         output_category_dir = os.path.join(output_dataset_dir, category_name)
            
    #         # Ensure output category directory exists
    #         os.makedirs(output_category_dir, exist_ok=True)

    #         # Iterate over each image in the category directory
    #         for image_name in os.listdir(input_category_dir):
    #             image_path = os.path.join(input_category_dir, image_name)
                
    #             # Skip directories or non-image files
    #             if os.path.isdir(image_path) or not image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
    #                 continue
                
    #             # Upscale the image
    #             upscaled_image = upscale_image(image_path, upscale_target)
                
    #             if upscaled_image:
    #                 # Save the upscaled image to the output directory
    #                 output_image_path = os.path.join(output_category_dir, image_name)
    #                 upscaled_image.save(output_image_path)
    #                 print(f"Processed and saved: {image_name} to {output_image_path}")
    #             else:
    #                 print(f"Failed to process image {image_name}")

# %%
input_dir = "/mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid"
output_dir = "/mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled"
process_and_upscale_images(input_dir, output_dir)
# Out:
# Processed and saved: 059_050_16.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/059_050_16.png
# Processed and saved: 056_996_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/056_996_14.png
# Processed and saved: 021_312_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/021_312_10.png
# Processed and saved: 035_036_3.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/035_036_3.png
# Processed and saved: 041_063_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/041_063_10.png
# Processed and saved: 059_050_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/059_050_11.png
# Processed and saved: 050_059_16.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/050_059_16.png
# Processed and saved: 001_870_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/001_870_5.png
# Processed and saved: 058_039_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/058_039_4.png
# Processed and saved: 063_041_25.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/063_041_25.png
# Processed and saved: 059_050_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/059_050_2.png
# Processed and saved: 001_870_13.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/001_870_13.png
# Processed and saved: 061_080_9.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/061_080_9.png
# Processed and saved: 051_332_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/051_332_0.png
# Processed and saved: 028_068_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/028_068_2.png
# Processed and saved: 033_097_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/033_097_0.png
# Processed and saved: 052_108_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/052_108_2.png
# Processed and saved: 020_344_3.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/020_344_3.png
# Processed and saved: 012_026_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/012_026_11.png
# Processed and saved: 000_003_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/000_003_2.png
# Processed and saved: 031_163_6.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/031_163_6.png
# Processed and saved: 030_193_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/030_193_2.png
# Processed and saved: 049_946_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/049_946_1.png
# Processed and saved: 031_163_15.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/031_163_15.png
# Processed and saved: 005_010_13.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/005_010_13.png
# Processed and saved: 058_039_20.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/058_039_20.png
# Processed and saved: 032_944_8.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/032_944_8.png
# Processed and saved: 044_945_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/044_945_4.png
# Processed and saved: 019_018_33.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/019_018_33.png
# Processed and saved: 039_058_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/039_058_4.png
# Processed and saved: 048_029_13.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/048_029_13.png
# Processed and saved: 064_991_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation
png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/008_990_9.png
# Processed and saved: 034_590_13.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/034_590_13.png
# Processed and saved: 021_312_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/021_312_11.png
# Processed and saved: 061_080_6.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/061_080_6.png
# Processed and saved: 055_147_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/055_147_11.png
# Processed and saved: 043_110_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/043_110_12.png
# Processed and saved: 014_790_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/014_790_1.png
# Processed and saved: 011_805_24.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/011_805_24.png
# Processed and saved: 008_990_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/008_990_14.png
# Processed and saved: 016_209_20.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/016_209_20.png
# Processed and saved: 045_889_9.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/045_889_9.png
# Processed and saved: 008_990_22.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/008_990_22.png
# Processed and saved: 039_058_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/039_058_14.png
# Processed and saved: 039_058_15.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/039_058_15.png
# Processed and saved: 009_027_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/009_027_14.png
# Processed and saved: 017_803_15.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/017_803_15.png
# Processed and saved: 011_805_9.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/fake/011_805_9.png
# ...
# Processed and saved: 063_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/063_1.png
# Processed and saved: 004_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/004_10.png
# Processed and saved: 023_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/023_14.png
# Processed and saved: 063_25.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/063_25.png
# Processed and saved: 011_3.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_3.png
# Processed and saved: 016_6.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/016_6.png
# Processed and saved: 019_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/019_12.png
# Processed and saved: 049_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/049_1.png
# Processed and saved: 042_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/042_5.png
# Processed and saved: 021_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/021_1.png
# Processed and saved: 013_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/013_5.png
# Processed and saved: 059_7.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/059_7.png
# Processed and saved: 037_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/037_10.png
# Processed and saved: 058_18.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/058_18.png
# Processed and saved: 017_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/017_11.png
# Processed and saved: 011_23.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_23.png
# Processed and saved: 064_9.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/064_9.png
# Processed and saved: 011_20.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_20.png
# Processed and saved: 026_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/026_0.png
# Processed and saved: 044_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/044_0.png
# Processed and saved: 046_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/046_2.png
# Processed and saved: 002_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/002_11.png
# Processed and saved: 024_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/024_11.png
# Processed and saved: 056_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/056_12.png
# Processed and saved: 004_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/004_0.png
# Processed and saved: 039_19.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/039_19.png
# Processed and saved: 000_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/000_4.png
# Processed and saved: 067_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/067_12.png
# Processed and saved: 057_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/057_0.png
# Processed and saved: 037_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/037_14.png
# Processed and saved: 063_33.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/063_33.png
# Processed and saved: 040_17.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/040_17.png
# Processed and saved: 043_6.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/043_6.png
# Processed and saved: 051_27.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/051_27.png
# Processed and saved: 031_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/031_0.png
# Processed and saved: 033_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/033_11.png
# Processed and saved: 009_3.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/009_3.png
# Processed and saved: 041_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/041_0.png
# Processed and saved: 060_24.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/060_24.png
# Processed and saved: 060_8.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/060_8.png
# Processed and saved: 056_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/056_4.png
# Processed and saved: 012_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/012_10.png
# Processed and saved: 047_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/047_0.png
# Processed and saved: 047_7.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/047_7.png
# Processed and saved: 031_7.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/031_7.png
# Processed and saved: 059_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/059_1.png
# Processed and saved: 046_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/046_11.png
# Processed and saved: 039_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/039_11.png
# Processed and saved: 002_20.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/002_20.png
# Processed and saved: 011_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_11.png
# Processed and saved: 026_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/026_12.png
# Processed and saved: 045_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/045_5.png
# Processed and saved: 044_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/044_5.png
# Processed and saved: 034_6.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/034_6.png
# Processed and saved: 029_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/029_12.png
# Processed and saved: 065_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/065_1.png
# Processed and saved: 002_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/002_14.png
# Processed and saved: 025_17.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/025_17.png
# Processed and saved: 035_8.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/035_8.png
# Processed and saved: 024_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/024_5.png
# Processed and saved: 011_43.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_43.png
# Processed and saved: 060_26.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/060_26.png
# Processed and saved: 044_1.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/044_1.png
# Processed and saved: 060_29.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/060_29.png
# Processed and saved: 066_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/066_12.png
# Processed and saved: 059_24.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/059_24.png
# Processed and saved: 011_37.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_37.png
# Processed and saved: 051_12.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/051_12.png
# Processed and saved: 054_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/054_10.png
# Processed and saved: 011_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_5.png
# Processed and saved: 048_7.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/048_7.png
# Processed and saved: 053_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/053_11.png
# Processed and saved: 055_3.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/055_3.png
# Processed and saved: 047_9.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/047_9.png
# Processed and saved: 004_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/004_5.png
# Processed and saved: 039_17.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/039_17.png
# Processed and saved: 012_8.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/012_8.png
# Processed and saved: 001_10.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/001_10.png
# Processed and saved: 051_16.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/051_16.png
# Processed and saved: 027_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/027_0.png
# Processed and saved: 014_6.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/014_6.png
# Processed and saved: 058_3.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/058_3.png
# Processed and saved: 019_35.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/019_35.png
# Processed and saved: 065_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/065_2.png
# Processed and saved: 041_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/041_5.png
# Processed and saved: 009_0.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/009_0.png
# Processed and saved: 064_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/064_14.png
# Processed and saved: 013_3.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/013_3.png
# Processed and saved: 060_13.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/060_13.png
# Processed and saved: 051_20.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/051_20.png
# Processed and saved: 019_15.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/019_15.png
# Processed and saved: 019_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/019_2.png
# Processed and saved: 059_20.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/059_20.png
# Processed and saved: 026_11.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/026_11.png
# Processed and saved: 059_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/059_14.png
# Processed and saved: 034_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/034_5.png
# Processed and saved: 019_25.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/019_25.png
# Processed and saved: 064_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/064_4.png
# Processed and saved: 058_7.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/058_7.png
# Processed and saved: 012_7.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/012_7.png
# Processed and saved: 009_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/009_5.png
# Processed and saved: 061_8.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/061_8.png
# Processed and saved: 065_5.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/065_5.png
# Processed and saved: 009_17.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/009_17.png
# Processed and saved: 014_19.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/014_19.png
# Processed and saved: 028_13.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/028_13.png
# Processed and saved: 058_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/058_4.png
# Processed and saved: 019_19.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/019_19.png
# Processed and saved: 023_15.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/023_15.png
# Processed and saved: 059_23.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/059_23.png
# Processed and saved: 043_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/043_4.png
# Processed and saved: 011_25.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/011_25.png
# Processed and saved: 030_4.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/030_4.png
# Processed and saved: 066_14.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/066_14.png
# Processed and saved: 067_2.png to /mnt/documents/Minor-Project/Datasets/Combined_Dataset/thousand_vid_upscaled/validation/real/067_2.png
